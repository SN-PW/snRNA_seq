# %%
Extract_control_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_control_GSE139107_MouseIRI.metadata.txt"

Extract_control_meta_f = open(Extract_control_meta,'r',encoding='utf-8')
l_meta = []
x = 0
for line in Extract_control_meta_f:
    l_meta.append(line.split())
    x += 1
      
print(x)
# Out:
# 26654

# %%
meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/GSE139107_MouseIRI.metadataのコピー.txt"

meta_f = open(meta, 'r',encoding = 'utf-8')
l_meta = []
for line in meta_f:
    l_meta.append(line.split())
print(len(l_meta))
print(l_meta[0])
# Out:
# 126579
# ['Group', 'Replicates', 'celltype']

# %%
#PTS1
PTS1 = []

l_meta = []
Extract_control_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_control_GSE139107_MouseIRI.metadata.txt"

Extract_control_meta_f = open(Extract_control_meta,'r',encoding='utf-8')
for line in Extract_control_meta_f:
    l_meta.append(line.split())

for line in l_meta:
    if line[3] == 'PTS1':
        PTS1.append(line[0]) 
        
f = open('Test_control_PTS1.txt','w')

for line in PTS1:
    f.write(line)
    f.write('\t')
f.write('\n')

control = "/Users/sakitakeshita/Desktop/ドライ解析/Dataset_Paper/Processed_data/Processed_data_from_GEO/LogNormalize2_IRI_ctrl.txt"

control_f = open(control,'r',encoding='utf-8')
l = []
for line in control_f:
    l.append(line.split())


for i in range(26654):
    for line in PTS1:
        if line == l[0][i]:
            f.write(l[1][i+1])
            f.write('\t')
            x += 1
f.write('\n')

y = 0
f.write("Slc5a8")
f.write('\t')
for i in range(26654):
    for line in PTS1:
        if line == l[0][i]:
            f.write(l[2][i+1])
            f.write('\t')
            y += 1 
f.write('\n')

z = 0
f.write("Slc5a12")
f.write('\t')
for i in range(26654):
    for line in PTS1:
        if line == l[0][i]:
            f.write(l[3][i+1])
            f.write('\t')
            z += 1
f.write('\n')
f.close()

print(len(l[0]))
# Out:
# 26654

# %%
#PTS1
PTS1 = []

l_meta = []
Extract_control_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_control_GSE139107_MouseIRI.metadata.txt"

Extract_control_meta_f = open(Extract_control_meta,'r',encoding='utf-8')
for line in Extract_control_meta_f:
    l_meta.append(line.split())

for line in l_meta:
    if line[3] == 'PTS1':
        PTS1.append(line[0]) 
        
f = open('Test2_control_PTS1.txt','w')

for line in PTS1:
    f.write(line)
    f.write('\t')
f.write('\n')

control = "/Users/sakitakeshita/Desktop/ドライ解析/Dataset_Paper/Processed_data/Processed_data_from_GEO/LogNormalize2_IRI_ctrl.txt"

control_f = open(control,'r',encoding='utf-8')
l = []
for line in control_f:
    l.append(line.split())


for i in range(26654):
    for line in PTS1:
        if line == l[0][i]:
            f.write(l[1][i+1])
            f.write('\t')
            x += 1
f.write('\n')

# %%
#PTS2
PTS2 = []

l_meta = []
Extract_control_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_control_GSE139107_MouseIRI.metadata.txt"

Extract_control_meta_f = open(Extract_control_meta,'r',encoding='utf-8')
for line in Extract_control_meta_f:
    l_meta.append(line.split())

for line in l_meta:
    if line[3] == 'PTS2':
        PTS2.append(line[0]) 
        
f = open('Norm_control_PTS2.txt','w')

for line in PTS2:
    f.write(line)
    f.write('\t')
f.write('\n')

Extract_control = "/Users/sakitakeshita/Desktop/ドライ解析/Data set & Paper/Processed data/Extract_Norm_ctrl.txt"

Extract_control_f = open(Extract_control,'r',encoding='utf-8')
l = []
for line in Extract_control_f:
    l.append(line.split())

x = 0
f.write("Slc1a5")
f.write('\t')
for i in range(26654):
    for line in PTS2:
        if line == l[0][i]:
            f.write(l[1][i+1])
            f.write('\t')
            x += 1
f.write('\n')

y = 0
f.write("Slc5a8")
f.write('\t')
for i in range(26654):
    for line in PTS2:
        if line == l[0][i]:
            f.write(l[2][i+1])
            f.write('\t')
            y += 1 
f.write('\n')

z = 0
f.write("Slc5a12")
f.write('\t')
for i in range(26654):
    for line in PTS2:
        if line == l[0][i]:
            f.write(l[3][i+1])
            f.write('\t')
            z += 1
f.write('\n')

print(len(l[0]))
print(z)
# Out:
# 26654
# 4106

# %%
#PTS3
PTS3 = []

l_meta = []
Extract_control_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_control_GSE139107_MouseIRI.metadata.txt"

Extract_control_meta_f = open(Extract_control_meta,'r',encoding='utf-8')
for line in Extract_control_meta_f:
    l_meta.append(line.split())

for line in l_meta:
    if line[3] == 'PTS3':
        PTS3.append(line[0]) 
        
f = open('Norm_control_PTS3.txt','w')

for line in PTS3:
    f.write(line)
    f.write('\t')
f.write('\n')

Extract_control = "/Users/sakitakeshita/Desktop/ドライ解析/Data set & Paper/Processed data/Extract_Norm_ctrl.txt"

Extract_control_f = open(Extract_control,'r',encoding='utf-8')
l = []
for line in Extract_control_f:
    l.append(line.split())

x = 0
f.write("Slc1a5")
f.write('\t')
for i in range(26654):
    for line in PTS3:
        if line == l[0][i]:
            f.write(l[1][i+1])
            f.write('\t')
            x += 1
f.write('\n')

y = 0
f.write("Slc5a8")
f.write('\t')
for i in range(26654):
    for line in PTS3:
        if line == l[0][i]:
            f.write(l[2][i+1])
            f.write('\t')
            y += 1 
f.write('\n')

z = 0
f.write("Slc5a12")
f.write('\t')
for i in range(26654):
    for line in PTS3:
        if line == l[0][i]:
            f.write(l[3][i+1])
            f.write('\t')
            z += 1
f.write('\n')
print(len(l[0]))
print(z)
# Out:
# 26654
# 1937

# %%
#NewPT1
NewPT1 = []

l_meta = []
Extract_control_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_control_GSE139107_MouseIRI.metadata.txt"

Extract_control_meta_f = open(Extract_control_meta,'r',encoding='utf-8')
for line in Extract_control_meta_f:
    l_meta.append(line.split())

for line in l_meta:
    if line[3] == 'NewPT1':
        NewPT1.append(line[0]) 
        
f = open('Norm_control_NewPT1.txt','w')

for line in NewPT1:
    f.write(line)
    f.write('\t')
f.write('\n')

Extract_control = "/Users/sakitakeshita/Desktop/ドライ解析/Data set & Paper/Processed data/Extract_Norm_ctrl.txt"

Extract_control_f = open(Extract_control,'r',encoding='utf-8')
l = []
for line in Extract_control_f:
    l.append(line.split())

x = 0
f.write("Slc1a5")
f.write('\t')
for i in range(26654):
    for line in NewPT1:
        if line == l[0][i]:
            f.write(l[1][i+1])
            f.write('\t')
            x += 1
f.write('\n')

y = 0
f.write("Slc5a8")
f.write('\t')
for i in range(26654):
    for line in NewPT1:
        if line == l[0][i]:
            f.write(l[2][i+1])
            f.write('\t')
            y += 1 
f.write('\n')

z = 0
f.write("Slc5a12")
f.write('\t')
for i in range(26654):
    for line in NewPT1:
        if line == l[0][i]:
            f.write(l[3][i+1])
            f.write('\t')
            z += 1
f.write('\n')
print(len(l[0]))
print(z)
# Out:
# 26654
# 153

# %%
#NewPT2
NewPT2 = []

l_meta = []
Extract_control_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_control_GSE139107_MouseIRI.metadata.txt"

Extract_control_meta_f = open(Extract_control_meta,'r',encoding='utf-8')
for line in Extract_control_meta_f:
    l_meta.append(line.split())

for line in l_meta:
    if line[3] == 'NewPT2':
        NewPT2.append(line[0]) 
        
f = open('Norm_control_NewPT2.txt','w')

for line in NewPT2:
    f.write(line)
    f.write('\t')
f.write('\n')

Extract_control = "/Users/sakitakeshita/Desktop/ドライ解析/Data set & Paper/Processed data/Extract_Norm_ctrl.txt"

Extract_control_f = open(Extract_control,'r',encoding='utf-8')
l = []
for line in Extract_control_f:
    l.append(line.split())

x = 0
f.write("Slc1a5")
f.write('\t')
for i in range(26654):
    for line in NewPT2:
        if line == l[0][i]:
            f.write(l[1][i+1])
            f.write('\t')
            x += 1
f.write('\n')

y = 0
f.write("Slc5a8")
f.write('\t')
for i in range(26654):
    for line in NewPT2:
        if line == l[0][i]:
            f.write(l[2][i+1])
            f.write('\t')
            y += 1 
f.write('\n')

z = 0
f.write("Slc5a12")
f.write('\t')
for i in range(26654):
    for line in NewPT2:
        if line == l[0][i]:
            f.write(l[3][i+1])
            f.write('\t')
            z += 1
f.write('\n')
print(len(l[0]))
print(z)
# Out:
# 26654
# 54

# %%
#PTS1 new file
PTS1 = []

meta = []
Ext_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_control_GSE139107_MouseIRI.metadata.txt"

Ext_meta_f = open(Ext_meta,'r',encoding='utf-8')
for line in Ext_meta_f:
    meta.append(line.split())

for line in meta:
    if line[3] == 'PTS1':
        PTS1.append(line[0]) 
        
f = open('ctrl_PTS1.txt','w')

for line in PTS1:
    f.write(line)
    f.write('\t')
f.write('\n')

ctrl = "/Users/sakitakeshita/Desktop/ドライ解析/Dataset_Paper/Processed_data/Processed_data_from_GEO/GSE139107_MouseIRI_control.dge.txt"
ctrl_f = open(ctrl,'r',encoding='utf-8')

l = []
for line in ctrl_f:
    l.append(line.split())

#Cell Barcodesを書く
for j in range(1,27134):
    f.write(l[j][0])
    f.write('\t')
    
    for line in PTS1:
        for i in range(26654): 
            if line == l[0][i]:
                f.write(l[j][i+1])
                f.write('\t')
    f.write('\n')
    
f.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-eddeb63305c9> in <module>
#      34     for line in PTS1:
#      35         for i in range(26654):
# ---> 36             if line == l[0][i]:
#      37                 f.write(l[j][i+1])
#      38                 f.write('\t')
#
# KeyboardInterrupt:

# %%
#PTS1 new file
PTS1 = []

meta = []
Ext_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_control_GSE139107_MouseIRI.metadata.txt"

Ext_meta_f = open(Ext_meta,'r',encoding='utf-8')
for line in Ext_meta_f:
    meta.append(line.split())

for line in meta:
    if line[3] == 'PTS1':
        PTS1.append(line[0]) 
        
f = open('Speed_ctrl_PTS1.txt','w')

for line in PTS1:
    f.write(line)
    f.write('\t')
f.write('\n')

ctrl = "/Users/sakitakeshita/Desktop/ドライ解析/Dataset_Paper/Processed_data/Processed_data_from_GEO/GSE139107_MouseIRI_control.dge.txt"
ctrl_f = open(ctrl,'r',encoding='utf-8')

l = []
for line in ctrl_f:
    l.append(line.split())

#Cell Barcodesを書く
for j in range(1,27134):
    f.write(l[j][0])
    f.write('\t')
    
    for line in PTS1:
        for i in range(26654): 
            if line == l[0][i]:
                f.write(l[j][i+1])
                f.write('\t')
                break
    f.write('\n')
    
f.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-1011a15404b9> in <module>
#      34     for line in PTS1:
#      35         for i in range(26654):
# ---> 36             if line == l[0][i]:
#      37                 f.write(l[j][i+1])
#      38                 f.write('\t')
#
# KeyboardInterrupt:

# %%
#PTS1 new file
PTS1 = []

meta = []
Ext_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_control_GSE139107_MouseIRI.metadata.txt"

Ext_meta_f = open(Ext_meta,'r',encoding='utf-8')
for line in Ext_meta_f:
    meta.append(line.split())

for line in meta:
    if line[3] == 'PTS1':
        PTS1.append(line[0]) 
        
f = open('SpeedTest_ctrl_PTS1.txt','w')

for line in PTS1:
    f.write(line)
    f.write('\t')
f.write('\n')

ctrl = "/Users/sakitakeshita/Desktop/ドライ解析/Dataset_Paper/Processed_data/Processed_data_from_GEO/GSE139107_MouseIRI_control.dge.txt"
ctrl_f = open(ctrl,'r',encoding='utf-8')

l = []
for line in ctrl_f:
    l.append(line.split())


for j in range(1,27134):
    f.write(l[j][0])
    f.write('\t')
    
    k = 0
    for line in PTS1:
        for i in range(k,26654): 
            if line == l[0][i]:
                f.write(l[j][i+1])
                f.write('\t')
                k = i
                break
    f.write('\n')
    
f.close()

# %%
ctrl = "/Users/sakitakeshita/Desktop/Desktop/ドライ解析/Dataset_Paper/Processed_data/Processed_data_from_GEO/GSE139107_MouseIRI_control.dge.txt"
ctrl_f = open(ctrl,'r',encoding='utf-8')

l = []
for line in ctrl_f:
    l.append(line.split())
print(len(l[0]))
print(len(l[1]))
print(len(l[2]))
# Out:
# 26654
# 26655
# 26655

# %%
#PTS2 new file
PTS2 = []

meta = []
Ext_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_control_GSE139107_MouseIRI.metadata.txt"

Ext_meta_f = open(Ext_meta,'r',encoding='utf-8')
for line in Ext_meta_f:
    meta.append(line.split())

for line in meta:
    if line[3] == 'PTS2':
        PTS2.append(line[0]) 
        
f = open('SpeedTest_ctrl_PTS2.txt','w')

for line in PTS2:
    f.write(line)
    f.write('\t')
f.write('\n')

ctrl = "/Users/sakitakeshita/Desktop/ドライ解析/Dataset_Paper/Processed_data/Processed_data_from_GEO/GSE139107_MouseIRI_control.dge.txt"
ctrl_f = open(ctrl,'r',encoding='utf-8')

l = []
for line in ctrl_f:
    l.append(line.split())


for j in range(1,27134):
    f.write(l[j][0])
    f.write('\t')
    
    k = 0
    for line in PTS2:
        for i in range(k,26654): 
            if line == l[0][i]:
                f.write(l[j][i+1])
                f.write('\t')
                k = i
                break
    f.write('\n')
    
f.close()

# %%
#PTS3 new file
PTS3 = []

meta = []
Ext_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_control_GSE139107_MouseIRI.metadata.txt"

Ext_meta_f = open(Ext_meta,'r',encoding='utf-8')
for line in Ext_meta_f:
    meta.append(line.split())

for line in meta:
    if line[3] == 'PTS3':
        PTS3.append(line[0]) 
        
f = open('SpeedTest_ctrl_PTS3.txt','w')

for line in PTS3:
    f.write(line)
    f.write('\t')
f.write('\n')

ctrl = "/Users/sakitakeshita/Desktop/ドライ解析/Dataset_Paper/Processed_data/Processed_data_from_GEO/GSE139107_MouseIRI_control.dge.txt"
ctrl_f = open(ctrl,'r',encoding='utf-8')

l = []
for line in ctrl_f:
    l.append(line.split())


for j in range(1,27134):
    f.write(l[j][0])
    f.write('\t')
    
    k = 0
    for line in PTS3:
        for i in range(k,26654): 
            if line == l[0][i]:
                f.write(l[j][i+1])
                f.write('\t')
                k = i
                break
    f.write('\n')
    
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-42cbf7d1288e> in <module>
#      21
#      22 ctrl = "/Users/sakitakeshita/Desktop/ドライ解析/Dataset_Paper/Processed_data/Processed_data_from_GEO/GSE139107_MouseIRI_control.dge.txt"
# ---> 23 ctrl_f = open(ctrl,'r',encoding='utf-8')
#      24
#      25 l = []
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/sakitakeshita/Desktop/ドライ解析/Dataset_Paper/Processed_data/Processed_data_from_GEO/GSE139107_MouseIRI_control.dge.txt'
