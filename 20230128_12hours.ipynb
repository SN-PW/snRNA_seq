# %%
Extract_12hours_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_12hours_GSE139107_MouseIRI.metadata.txt"

Extract_12hours_meta_f = open(Extract_12hours_meta,'r',encoding='utf-8')
l_meta = []
for line in Extract_12hours_meta_f:
    l_meta.append(line.split())
print(len(l_meta))
# Out:
# 20460

# %%
Control = []
l_meta = []

Extract_control_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_control_GSE139107_MouseIRI.metadata.txt"

Extract_control_meta_f = open(Extract_control_meta,'r',encoding='utf-8')
for line in Extract_control_meta_f:
    l_meta.append(line.split())

for line in l_meta:
    if line[3] == 'PTS1':
        PTS1.append(line[0]) 
        
f = open('test1_12hours_PTS1.txt','w')

for line in PTS1:
    f.write(line)
    f.write('\t')
f.write('\n')

Extract_12hours = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_GSE139107_MouseIRI_12hours.dge.txt"

Extract_12hours_f = open(Extract_12hours,'r',encoding='utf-8')
l = []
for line in Extract_12hours_f:
    l.append(line.split())

x = 0
for i in range(20460):
    for line in PTS1:
        if line == l[0][i]:
            f.write(l[1][i+1])
            f.write('\t')
            x += 1
f.write('\n')

y = 0
for i in range(20460):
    for line in PTS1:
        if line == l[0][i]:
            f.write(l[2][i+1])
            f.write('\t')
            y += 1 
f.write('\n')

z = 0
for i in range(20460):
    for line in PTS1:
        if line == l[0][i]:
            f.write(l[3][i+1])
            f.write('\t')
            z += 1
f.write('\n')
print(len(l[0]))
# Out:
# 20460

# %%
PTS1 = []

l_meta = []
Extract_12hours_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_12hours_GSE139107_MouseIRI.metadata.txt"

Extract_12hours_meta_f = open(Extract_12hours_meta,'r',encoding='utf-8')
for line in Extract_12hours_meta_f:
    l_meta.append(line.split())

for line in l_meta:
    if line[3] == 'PTS1':
        PTS1.append(line[0]) 
        
f = open('Norm_12hours_PTS1.txt','w')

for line in PTS1:
    f.write(line)
    f.write('\t')
f.write('\n')

Extract_12hours = "/Users/sakitakeshita/Desktop/ドライ解析/Data set & Paper/Processed data/Extract_Norm_12h.txt"
Extract_12hours_f = open(Extract_12hours,'r',encoding='utf-8')
l = []
for line in Extract_12hours_f:
    l.append(line.split())

x = 0
f.write(l[1][0])
f.write('\t')
for i in range(20460):
    for line in PTS1:
        if line == l[0][i]:
            f.write(l[1][i+1])
            f.write('\t')
            x += 1
f.write('\n')

y = 0
f.write(l[2][0])
f.write('\t')
for i in range(20460):
    for line in PTS1:
        if line == l[0][i]:
            f.write(l[2][i+1])
            f.write('\t')
            y += 1 
f.write('\n')

z = 0
f.write(l[3][0])
f.write('\t')
for i in range(20460):
    for line in PTS1:
        if line == l[0][i]:
            f.write(l[3][i+1])
            f.write('\t')
            z += 1
f.write('\n')
print(PTS1)
# Out:
# ['IRI12h1b1_AAAGATGGTTAAGATG', 'IRI12h1b1_AAAGATGTCTAACCGA', 'IRI12h1b1_AAAGCAACACGGTAGA', 'IRI12h1b1_AAAGCAATCTGATTCT', 'IRI12h1b1_AAAGTAGAGACAGGCT', 'IRI12h1b1_AAATGCCCAATGACCT', 'IRI12h1b1_AACACGTTCAAAGTAG', 'IRI12h1b1_AACCATGAGCTCCCAG', 'IRI12h1b1_AACCGCGTCACGGTTA', 'IRI12h1b1_AACCGCGTCGAACGGA', 'IRI12h1b1_AACTCCCAGTAGATGT', 'IRI12h1b1_AACTTTCCACTTAACG', 'IRI12h1b1_AACTTTCCATCGGTTA', 'IRI12h1b1_AAGACCTTCCTGTAGA', 'IRI12h1b1_AAGGTTCAGCAGGCTA', 'IRI12h1b1_AATCCAGTCGCACTCT', 'IRI12h1b1_AATCCAGTCTACTATC', 'IRI12h1b1_AATCGGTAGTCCGTAT', 'IRI12h1b1_AATCGGTTCGTGTAGT', 'IRI12h1b1_ACACCCTTCTGAGGGA', 'IRI12h1b1_ACACCGGCACATTAGC', 'IRI12h1b1_ACAGCCGTCTACTTAC', 'IRI12h1b1_ACATCAGAGGGATCTG', 'IRI12h1b1_ACCTTTACAAACTGCT', 'IRI12h1b1_ACCTTTACATCCCATC', 'IRI12h1b1_ACGAGCCTCACGAAGG', 'IRI12h1b1_ACGATACTCCCTCAGT', 'IRI12h1b1_ACGATGTTCTGCTTGC', 'IRI12h1b1_ACGCCAGAGATCCCAT', 'IRI12h1b1_ACGCCGACAATGTTGC', 'IRI12h1b1_ACGGCCAAGTAAGTAC', 'IRI12h1b1_ACTGAGTCATTACGAC', 'IRI12h1b1_ACTGAGTGTCTAAAGA', 'IRI12h
# ...

# %%
#PTS2
PTS2 = []

l_meta = []
Extract_12hours_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_12hours_GSE139107_MouseIRI.metadata.txt"

Extract_12hours_meta_f = open(Extract_12hours_meta,'r',encoding='utf-8')
for line in Extract_12hours_meta_f:
    l_meta.append(line.split())
    
for line in l_meta:
    if line[3] == 'PTS2':
        PTS2.append(line[0])
        
f = open('Norm_12hours_PTS2.txt','w')

for line in PTS2:
    f.write(line)
    f.write('\t')
f.write('\n')

Extract_12hours  = "/Users/sakitakeshita/Desktop/ドライ解析/Data set & Paper/Processed data/Extract_Norm_12h.txt"
Extract_12hours_f = open(Extract_12hours,'r',encoding='utf-8')
l = []
for line in Extract_12hours_f:
    l.append(line.split())

x = 0
f.write(l[1][0])
f.write('\t')
for i in range(20460):
    for line in PTS2:
        if line == l[0][i]:
            f.write(l[1][i+1])
            f.write('\t')
            x += 1
f.write('\n')

y = 0
f.write(l[2][0])
f.write('\t')
for i in range(20460):
    for line in PTS2:
        if line == l[0][i]:
            f.write(l[2][i+1])
            f.write('\t')
            y += 1 
f.write('\n')

z = 0
f.write(l[3][0])
f.write('\t')
for i in range(20460):
    for line in PTS2:
        if line == l[0][i]:
            f.write(l[3][i+1])
            f.write('\t')
            z += 1
f.write('\n')
print(len(PTS2))
# Out:
# 1841

# %%
#PTS3
PTS3 = []

l_meta = []
Extract_12hours_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_12hours_GSE139107_MouseIRI.metadata.txt"

Extract_12hours_meta_f = open(Extract_12hours_meta,'r',encoding='utf-8')
for line in Extract_12hours_meta_f:
    l_meta.append(line.split())
    
for line in l_meta:
    if line[3] == 'PTS3':
        PTS3.append(line[0])
        
f = open('Norm_12hours_PTS3.txt','w')

for line in PTS3:
    f.write(line)
    f.write('\t')
f.write('\n')

Extract_12hours  = "/Users/sakitakeshita/Desktop/ドライ解析/Data set & Paper/Processed data/Extract_Norm_12h.txt"

Extract_12hours_f = open(Extract_12hours,'r',encoding='utf-8')
l = []
for line in Extract_12hours_f:
    l.append(line.split())

x = 0
f.write(l[1][0])
f.write('\t')
for i in range(20460):
    for line in PTS3:
        if line == l[0][i]:
            f.write(l[1][i+1])
            f.write('\t')
            x += 1
f.write('\n')

y = 0
f.write(l[2][0])
f.write('\t')
for i in range(20460):
    for line in PTS3:
        if line == l[0][i]:
            f.write(l[2][i+1])
            f.write('\t')
            y += 1 
f.write('\n')

z = 0
f.write(l[3][0])
f.write('\t')
for i in range(20460):
    for line in PTS3:
        if line == l[0][i]:
            f.write(l[3][i+1])
            f.write('\t')
            z += 1
f.write('\n')
print(len(PTS3))
print(z)
# Out:
# 361
# 361

# %%
#NewPT1
NewPT1 = []

l_meta = []
Extract_12hours_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_12hours_GSE139107_MouseIRI.metadata.txt"

Extract_12hours_meta_f = open(Extract_12hours_meta,'r',encoding='utf-8')
for line in Extract_12hours_meta_f:
    l_meta.append(line.split())
    
for line in l_meta:
    if line[3] == 'NewPT1':
        NewPT1.append(line[0])
        
f = open('Norm_12hours_NewPT1.txt','w')

for line in NewPT1:
    f.write(line)
    f.write('\t')
f.write('\n')

Extract_12hours  = "/Users/sakitakeshita/Desktop/ドライ解析/Data set & Paper/Processed data/Extract_Norm_12h.txt"

Extract_12hours_f = open(Extract_12hours,'r',encoding='utf-8')
l = []
for line in Extract_12hours_f:
    l.append(line.split())

x = 0
f.write(l[1][0])
f.write('\t')
for i in range(20460):
    for line in NewPT1:
        if line == l[0][i]:
            f.write(l[1][i+1])
            f.write('\t')
            x += 1
f.write('\n')

y = 0
f.write(l[2][0])
f.write('\t')
for i in range(20460):
    for line in NewPT1:
        if line == l[0][i]:
            f.write(l[2][i+1])
            f.write('\t')
            y += 1 
f.write('\n')

z = 0
f.write(l[3][0])
f.write('\t')
for i in range(20460):
    for line in NewPT1:
        if line == l[0][i]:
            f.write(l[3][i+1])
            f.write('\t')
            z += 1
f.write('\n')
print(len(NewPT1))
print(z)
# Out:
# 2783
# 2783

# %%
#NewPT2
NewPT2 = []

l_meta = []
Extract_12hours_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_12hours_GSE139107_MouseIRI.metadata.txt"

Extract_12hours_meta_f = open(Extract_12hours_meta,'r',encoding='utf-8')
for line in Extract_12hours_meta_f:
    l_meta.append(line.split())
    
for line in l_meta:
    if line[3] == 'NewPT2':
        NewPT2.append(line[0])
        
f = open('Norm_12hours_NewPT2.txt','w')

for line in NewPT2:
    f.write(line)
    f.write('\t')
f.write('\n')

Extract_12hours  = "/Users/sakitakeshita/Desktop/ドライ解析/Data set & Paper/Processed data/Extract_Norm_12h.txt"

Extract_12hours_f = open(Extract_12hours,'r',encoding='utf-8')
l = []
for line in Extract_12hours_f:
    l.append(line.split())

x = 0
f.write(l[1][0])
f.write('\t')
for i in range(20460):
    for line in NewPT2:
        if line == l[0][i]:
            f.write(l[1][i+1])
            f.write('\t')
            x += 1
f.write('\n')

y = 0
f.write(l[2][0])
f.write('\t')
for i in range(20460):
    for line in NewPT2:
        if line == l[0][i]:
            f.write(l[2][i+1])
            f.write('\t')
            y += 1 
f.write('\n')

z = 0
f.write(l[3][0])
f.write('\t')
for i in range(20460):
    for line in NewPT2:
        if line == l[0][i]:
            f.write(l[3][i+1])
            f.write('\t')
            z += 1
f.write('\n')
print(len(NewPT2))
print(z)
# Out:
# 355
# 355

# %%
#PTS1 new file
PTS1 = []

meta = []
Ext_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_12hours_GSE139107_MouseIRI.metadata.txt"

Ext_meta_f = open(Ext_meta,'r',encoding='utf-8')
for line in Ext_meta_f:
    meta.append(line.split())

for line in meta:
    if line[3] == 'PTS1':
        PTS1.append(line[0]) 
        
f = open('SpeedTest_12hours_PTS1.txt','w')

for line in PTS1:
    f.write(line)
    f.write('\t')
f.write('\n')

twel = "/Users/sakitakeshita/Desktop/ドライ解析/Dataset_Paper/Processed_data/Processed_data_from_GEO/GSE139107_MouseIRI_12hours.dge.txt"
twel_f = open(twel,'r',encoding='utf-8')

l = []
for line in twel_f:
    l.append(line.split())


for j in range(1,27134):
    f.write(l[j][0])
    f.write('\t')
    k = 0
    for line in PTS1:
        for i in range(k,20460): 
            if line == l[0][i]:
                f.write(l[j][i+1])
                f.write('\t')
                k = i
                break
    f.write('\n')
    
f.close()

# %%
#PTS2 new file
PTS2 = []

meta = []
Ext_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_12hours_GSE139107_MouseIRI.metadata.txt"

Ext_meta_f = open(Ext_meta,'r',encoding='utf-8')
for line in Ext_meta_f:
    meta.append(line.split())

for line in meta:
    if line[3] == 'PTS2':
        PTS2.append(line[0]) 
        
f = open('SpeedTest_12hours_PTS2.txt','w')

for line in PTS2:
    f.write(line)
    f.write('\t')
f.write('\n')

twel = "/Users/sakitakeshita/Desktop/ドライ解析/Dataset_Paper/Processed_data/Processed_data_from_GEO/GSE139107_MouseIRI_12hours.dge.txt"
twel_f = open(twel,'r',encoding='utf-8')

l = []
for line in twel_f:
    l.append(line.split())


for j in range(1,27134):
    f.write(l[j][0])
    f.write('\t')
    k = 0
    for line in PTS2:
        for i in range(k,20460): 
            if line == l[0][i]:
                f.write(l[j][i+1])
                f.write('\t')
                k = i
                break
    f.write('\n')
    
f.close()

# %%
#PTS3 new file
PTS3 = []

meta = []
Ext_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_12hours_GSE139107_MouseIRI.metadata.txt"

Ext_meta_f = open(Ext_meta,'r',encoding='utf-8')
for line in Ext_meta_f:
    meta.append(line.split())

for line in meta:
    if line[3] == 'PTS3':
        PTS3.append(line[0]) 
        
f = open('SpeedTest_12hours_PTS3.txt','w')

for line in PTS3:
    f.write(line)
    f.write('\t')
f.write('\n')

twel = "/Users/sakitakeshita/Desktop/ドライ解析/Dataset_Paper/Processed_data/Processed_data_from_GEO/GSE139107_MouseIRI_12hours.dge.txt"
twel_f = open(twel,'r',encoding='utf-8')

l = []
for line in twel_f:
    l.append(line.split())


for j in range(1,27134):
    f.write(l[j][0])
    f.write('\t')
    k = 0
    for line in PTS3:
        for i in range(k,20460): 
            if line == l[0][i]:
                f.write(l[j][i+1])
                f.write('\t')
                k = i
                break
    f.write('\n')
    
f.close()
