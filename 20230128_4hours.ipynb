# %%
Whole_4hours = "/Users/sakitakeshita/Desktop/ドライ解析/Data set & Paper/Processed data/Processed data from GEO/GSE139107_MouseIRI_4hours.dgeのコピー.txt"

Whole_4hours_f = open(Whole_4hours,'r',encoding='utf-8')
l = []
for line in Whole_4hours_f:
    l.append(line.split())

print(l[0])
# Out:
# ['IRI4h1_AAACCTGAGATCTGCT', 'IRI4h1_AAACCTGAGATTACCC', 'IRI4h1_AAACCTGAGTGTTAGA', 'IRI4h1_AAACCTGCACCAACCG', 'IRI4h1_AAACCTGCAGCCTGTG', 'IRI4h1_AAACCTGCAGGGAGAG', 'IRI4h1_AAACCTGCATCTCCCA', 'IRI4h1_AAACCTGGTAGCGCTC', 'IRI4h1_AAACCTGGTAGCTAAA', 'IRI4h1_AAACCTGGTGACTACT', 'IRI4h1_AAACCTGGTGATGTGG', 'IRI4h1_AAACCTGGTTACGTCA', 'IRI4h1_AAACCTGTCAGTTGAC', 'IRI4h1_AAACCTGTCCTAGAAC', 'IRI4h1_AAACCTGTCCTCAATT', 'IRI4h1_AAACCTGTCGTCGTTC', 'IRI4h1_AAACCTGTCTGCAAGT', 'IRI4h1_AAACGGGAGCATGGCA', 'IRI4h1_AAACGGGCAAGCCATT', 'IRI4h1_AAACGGGCAAGGTTCT', 'IRI4h1_AAACGGGCACCTATCC', 'IRI4h1_AAACGGGCAGGGTATG', 'IRI4h1_AAACGGGGTACGCACC', 'IRI4h1_AAACGGGGTCAGAGGT', 'IRI4h1_AAACGGGGTCCGCTGA', 'IRI4h1_AAACGGGGTCTCCCTA', 'IRI4h1_AAACGGGGTGATGTGG', 'IRI4h1_AAACGGGGTGCAACGA', 'IRI4h1_AAACGGGGTGCCTGCA', 'IRI4h1_AAACGGGTCAGCGATT', 'IRI4h1_AAACGGGTCCAGATCA', 'IRI4h1_AAACGGGTCGCCAGCA', 'IRI4h1_AAACGGGTCTGAGTGT', 'IRI4h1_AAACGGGTCTGCTTGC', 'IRI4h1_AAAGATGAGAGACTTA', 'IRI4h1_AAAGATGAGCTACCTA', 'IRI4h1_AAAGATGAGGCGCTCT'
# ...

# %%
Whole_4hours = "/Users/sakitakeshita/Desktop/ドライ解析/Data set & Paper/Processed data/GSE139107_MouseIRI_4hours.dge.txt"

Whole_4hours_f = open(Whole_4hours,'r',encoding='utf-8')
l = []
for line in Whole_4hours_f:
    l.append(line.split())

print(len(l))
# Out:
# 27134

# %%
Extract_4hours_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_4hours_GSE139107_MouseIRI.metadata.txt"

Extract_4hours_meta_f = open(Extract_4hours_meta,'r',encoding='utf-8')
l_meta = []
for line in Extract_4hours_meta_f:
    l_meta.append(line.split())
print(l_meta)
# Out:
# [['IRI4h1_AAACCTGAGATCTGCT', '4hours', '1', 'CTAL2'], ['IRI4h1_AAACCTGAGATTACCC', '4hours', '1', 'NewPT1'], ['IRI4h1_AAACCTGAGTGTTAGA', '4hours', '1', 'EC1'], ['IRI4h1_AAACCTGCACCAACCG', '4hours', '1', 'DCT'], ['IRI4h1_AAACCTGCAGCCTGTG', '4hours', '1', 'MTAL'], ['IRI4h1_AAACCTGCAGGGAGAG', '4hours', '1', 'ICA'], ['IRI4h1_AAACCTGCATCTCCCA', '4hours', '1', 'CTAL2'], ['IRI4h1_AAACCTGGTAGCGCTC', '4hours', '1', 'Fib'], ['IRI4h1_AAACCTGGTAGCTAAA', '4hours', '1', 'PTS3'], ['IRI4h1_AAACCTGGTGACTACT', '4hours', '1', 'PTS3'], ['IRI4h1_AAACCTGGTGATGTGG', '4hours', '1', 'NewPT1'], ['IRI4h1_AAACCTGGTTACGTCA', '4hours', '1', 'PTS2'], ['IRI4h1_AAACCTGTCAGTTGAC', '4hours', '1', 'PTS2'], ['IRI4h1_AAACCTGTCCTAGAAC', '4hours', '1', 'PTS1'], ['IRI4h1_AAACCTGTCCTCAATT', '4hours', '1', 'PTS2'], ['IRI4h1_AAACCTGTCGTCGTTC', '4hours', '1', 'DCT-CNT'], ['IRI4h1_AAACCTGTCTGCAAGT', '4hours', '1', 'CTAL2'], ['IRI4h1_AAACGGGAGCATGGCA', '4hours', '1', 'Mø'], ['IRI4h1_AAACGGGCAAGCCATT', '4hours', '1', 'Mø'], ['IRI4h
# ...

# %%
PTS1 = []
PTS2 = []
PTS3 = []
NewPT1 = []
NewPT2 = []
NewPT3 = []
DTLATL= []
MTAL = []
CTAL1 = []
CTAL2 = []
MD = []
DCT = []
DCTCNT = []
CNT = [] 
CPC = []
MPC = []
ICA = []
ICB = []
Uro = []
Pod = []
PEC = []
EC1 = []
EC2 = []
Fib = []
PER = []
CNT = []
Mø = []
Tcell = [] 

l_meta = []
Extract_4hours_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_4hours_GSE139107_MouseIRI.metadata.txt"

Extract_4hours_meta_f = open(Extract_4hours_meta,'r',encoding='utf-8')
for line in Extract_4hours_meta_f:
    l_meta.append(line.split())

for line in l_meta:
    if line[3] == 'PTS1':
print(PTS1)
# Out:
# ['IRI4h1_AAACCTGTCCTAGAAC', 'IRI4h1_AAACGGGGTCCGCTGA', 'IRI4h1_AAAGATGGTGAAAGAG', 'IRI4h1_AAAGATGGTTAAGACA', 'IRI4h1_AAAGATGTCGTCCAGG', 'IRI4h1_AAAGTAGCACGGATAG', 'IRI4h1_AAAGTAGGTACCGCTG', 'IRI4h1_AAAGTAGGTATGAATG', 'IRI4h1_AAAGTAGTCAATAAGG', 'IRI4h1_AAATGCCCAATCGGTT', 'IRI4h1_AAATGCCCATGGTCTA', 'IRI4h1_AAATGCCGTAAGTGGC', 'IRI4h1_AACACGTGTTATCGGT', 'IRI4h1_AACCATGAGAAACCGC', 'IRI4h1_AACCATGCATCCTAGA', 'IRI4h1_AACCGCGAGTTAGCGG', 'IRI4h1_AACCGCGCAGACGCAA', 'IRI4h1_AACCGCGGTTGGTGGA', 'IRI4h1_AACCGCGGTTTCGCTC', 'IRI4h1_AACGTTGAGGAGCGAG', 'IRI4h1_AACTCCCAGGACGAAA', 'IRI4h1_AACTCCCTCACCCTCA', 'IRI4h1_AACTGGTAGAAACCGC', 'IRI4h1_AACTGGTAGTCGATAA', 'IRI4h1_AACTGGTCATACTACG', 'IRI4h1_AAGACCTGTCGTTGTA', 'IRI4h1_AAGACCTTCATGCATG', 'IRI4h1_AAGACCTTCTACCAGA', 'IRI4h1_AAGCCGCTCGAGCCCA', 'IRI4h1_AAGCCGCTCTGTGCAA', 'IRI4h1_AAGGAGCAGTACGTTC', 'IRI4h1_AAGGCAGTCGGTTAAC', 'IRI4h1_AAGGTTCGTTGCTCCT', 'IRI4h1_AAGTCTGAGACACGAC', 'IRI4h1_AAGTCTGGTACCTACA', 'IRI4h1_AAGTCTGGTCCGACGT', 'IRI4h1_AATCCAGTCAACGAAA'
# ...

# %%
#PTS1
l_meta = []
Extract_4hours_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_4hours_GSE139107_MouseIRI.metadata.txt"

Extract_4hours_meta_f = open(Extract_4hours_meta,'r',encoding='utf-8')
for line in Extract_4hours_meta_f:
    l_meta.append(line.split())
    
PTS1 = []
#UMIs of PTS1 cells
for line in l_meta:
    if line[3] == 'PTS1':
        PTS1.append(line[0]) 

f = open('Norm_4hour_PTS1.txt','w')

for line in PTS1:
    f.write(line)
    f.write('\t')
f.write('\n')

Extract_4hours = "/Users/sakitakeshita/Desktop/ドライ解析/Data set & Paper/Processed data/Extract_Norm_4h.txt"

Extract_4hours_f = open(Extract_4hours,'r',encoding='utf-8')
l = []
for line in Extract_4hours_f:
    l.append(line.split())

x = 0
f.write("Slc1a5")
f.write('\t')
for i in range(14486):
    for line in PTS1:
        if line == l[0][i]:
            f.write(l[1][i+1])
            f.write('\t')
            x += 1
f.write('\n')

y = 0
f.write("Slc5a8")
f.write('\t')
for i in range(14486):
    for line in PTS1:
        if line == l[0][i]:
            f.write(l[2][i+1])
            f.write('\t')
            y += 1
f.write('\n')

z = 0
f.write("Slc5a12")
f.write('\t')
for i in range(14486):
    for line in PTS1:
        if line == l[0][i]:
            f.write(l[3][i+1])
            f.write('\t')
            z += 1
f.write('\n')

print(len(PTS1))
print(z)
# Out:
# 1373
# 1373

# %%
#PTS2
l_meta = []
Extract_4hours_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_4hours_GSE139107_MouseIRI.metadata.txt"

Extract_4hours_meta_f = open(Extract_4hours_meta,'r',encoding='utf-8')
for line in Extract_4hours_meta_f:
    l_meta.append(line.split())
    
PTS2 = []

for line in l_meta:
    if line[3] == 'PTS2':
        PTS2.append(line[0]) 

f = open('Norm_4hour_PTS2.txt','w')

for line in PTS2:
    f.write(line)
    f.write('\t')
f.write('\n')

Extract_4hours = "/Users/sakitakeshita/Desktop/ドライ解析/Data set & Paper/Processed data/Extract_Norm_4h.txt"

Extract_4hours_f = open(Extract_4hours,'r',encoding='utf-8')
l = []
for line in Extract_4hours_f:
    l.append(line.split())

x = 0
f.write("Slc1a5")
f.write('\t')
for i in range(14486):
    for line in PTS2:
        if line == l[0][i]:
            f.write(l[1][i+1])
            f.write('\t')
            x += 1
f.write('\n')

y = 0
f.write("Slc5a8")
f.write('\t')
for i in range(14486):
    for line in PTS2:
        if line == l[0][i]:
            f.write(l[2][i+1])
            f.write('\t')
            y += 1
f.write('\n')

z = 0
f.write("Slc5a12")
f.write('\t')
for i in range(14486):
    for line in PTS2:
        if line == l[0][i]:
            f.write(l[3][i+1])
            f.write('\t')
            z += 1
f.write('\n')

print(len(PTS2))
print(z)
# Out:
# 2293
# 2293

# %%
#PTS3
l_meta = []
Extract_4hours_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_4hours_GSE139107_MouseIRI.metadata.txt"

Extract_4hours_meta_f = open(Extract_4hours_meta,'r',encoding='utf-8')
for line in Extract_4hours_meta_f:
    l_meta.append(line.split())
    
PTS3 = []

for line in l_meta:
    if line[3] == 'PTS3':
        PTS3.append(line[0]) 

f = open('Norm_4hour_PTS3.txt','w')

for line in PTS3:
    f.write(line)
    f.write('\t')
f.write('\n')

Extract_4hours = "/Users/sakitakeshita/Desktop/ドライ解析/Data set & Paper/Processed data/Extract_Norm_4h.txt"

Extract_4hours_f = open(Extract_4hours,'r',encoding='utf-8')
l = []
for line in Extract_4hours_f:
    l.append(line.split())

x = 0
f.write("Slc1a5")
f.write('\t')
for i in range(14486):
    for line in PTS3:
        if line == l[0][i]:
            f.write(l[1][i+1])
            f.write('\t')
            x += 1
f.write('\n')

y = 0
f.write("Slc5a8")
f.write('\t')
for i in range(14486):
    for line in PTS3:
        if line == l[0][i]:
            f.write(l[2][i+1])
            f.write('\t')
            y += 1
f.write('\n')

z = 0
f.write("Slc5a12")
f.write('\t')
for i in range(14486):
    for line in PTS3:
        if line == l[0][i]:
            f.write(l[3][i+1])
            f.write('\t')
            z += 1
f.write('\n')

print(len(PTS3))
print(z)
# Out:
# 460
# 460

# %%
#NewPT1
l_meta = []
Extract_4hours_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_4hours_GSE139107_MouseIRI.metadata.txt"

Extract_4hours_meta_f = open(Extract_4hours_meta,'r',encoding='utf-8')
for line in Extract_4hours_meta_f:
    l_meta.append(line.split())
    
NewPT1  = []

for line in l_meta:
    if line[3] == 'NewPT1':
        NewPT1.append(line[0]) 

f = open('Norm_4hour_NewPT1.txt','w')

for line in NewPT1:
    f.write(line)
    f.write('\t')
f.write('\n')

Extract_4hours = "/Users/sakitakeshita/Desktop/ドライ解析/Data set & Paper/Processed data/Extract_Norm_4h.txt"

Extract_4hours_f = open(Extract_4hours,'r',encoding='utf-8')
l = []
for line in Extract_4hours_f:
    l.append(line.split())

x = 0
f.write("Slc1a5")
f.write('\t')
for i in range(14486):
    for line in NewPT1:
        if line == l[0][i]:
            f.write(l[1][i+1])
            f.write('\t')           
f.write('\n')

z = 0
f.write("Slc5a8")
f.write('\t')
for i in range(14486):
    for line in NewPT1:
        if line == l[0][i]:
            f.write(l[2][i+1])
            f.write('\t')
f.write('\n')

z = 0
f.write("Slc5a12")
f.write('\t')
for i in range(14486):
    for line in NewPT1:
        if line == l[0][i]:
            f.write(l[3][i+1])
            f.write('\t')
f.write('\n')

print(len(NewPT1))
# Out:
# 2522

# %%
#NewPT2
l_meta = []
Extract_4hours_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_4hours_GSE139107_MouseIRI.metadata.txt"

Extract_4hours_meta_f = open(Extract_4hours_meta,'r',encoding='utf-8')
for line in Extract_4hours_meta_f:
    l_meta.append(line.split())
    
NewPT2  = []

for line in l_meta:
    if line[3] == 'NewPT2':
        NewPT2.append(line[0]) 

f = open('Norm_4hour_NewPT2.txt','w')

for line in NewPT2:
    f.write(line)
    f.write('\t')
f.write('\n')

Extract_4hours = "/Users/sakitakeshita/Desktop/ドライ解析/Data set & Paper/Processed data/Extract_Norm_4h.txt"

Extract_4hours_f = open(Extract_4hours,'r',encoding='utf-8')
l = []
for line in Extract_4hours_f:
    l.append(line.split())

f.write("Slc1a5")
f.write('\t')
for i in range(14486):
    for line in NewPT2:
        if line == l[0][i]:
            f.write(l[1][i+1])
            f.write('\t')
f.write('\n')

f.write("Slc5a8")
f.write('\t')
for i in range(14486):
    for line in NewPT2:
        if line == l[0][i]:
            f.write(l[2][i+1])
            f.write('\t')
f.write('\n')

f.write("Slc5a12")
f.write('\t')
for i in range(14486):
    for line in NewPT2:
        if line == l[0][i]:
            f.write(l[3][i+1])
            f.write('\t')
f.write('\n')

print(len(NewPT2))
# Out:
# 264

# %%
#NewPT2-Whole
l_meta = []
Extract_4hours_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_4hours_GSE139107_MouseIRI.metadata.txt"

Extract_4hours_meta_f = open(Extract_4hours_meta,'r',encoding='utf-8')
for line in Extract_4hours_meta_f:
    l_meta.append(line.split())
    
NewPT2  = []

for line in l_meta:
    if line[3] == 'NewPT2':
        NewPT2.append(line[0]) 

f = open('test_4hour_NewPT2_all.txt','w')

for line in NewPT2:
    f.write(line)
    f.write('\t')
f.write('\n')

all_4hours = "/Users/sakitakeshita/Desktop/ドライ解析/Data set & Paper/Processed data/GSE139107_MouseIRI_4hours.dge.txt"

all_4hours_f = open(all_4hours,'r',encoding='utf-8')
l = []
for line in all_4hours_f:
    l.append(line.split())

for j in range(1,27134):
    f.write(l[j][0])
    f.write('\t')
    for i in range(14486): 
        for line in NewPT2:
            if line == l[0][i]:
                f.write(l[j][i+1])
                f.write('\t')
    f.write('\n')

# %%
#PTS1 new file
PTS1 = []

meta = []
Ext_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_4hours_GSE139107_MouseIRI.metadata.txt"

Ext_meta_f = open(Ext_meta,'r',encoding='utf-8')
for line in Ext_meta_f:
    meta.append(line.split())

for line in meta:
    if line[3] == 'PTS1':
        PTS1.append(line[0]) 
        
f = open('4hours_PTS1.txt','w')

four = "/Users/sakitakeshita/Desktop/ドライ解析/Dataset_Paper/Processed_data/Processed_data_from_GEO/GSE139107_MouseIRI_4hours.dge.txt"
four_f = open(four,'r',encoding='utf-8')

l = []
for line in four_f:
    l.append(line.split())

#Cell Barcodesを書く
for j in range(1,27134):
    f.write(l[j][0])
    f.write('\t')
    
    for line in PTS1:
        for i in range(14486): 
            if line == l[0][i]:
                f.write(l[j][i+1])
                f.write('\t')
    f.write('\n')
    
f.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-397005983d70> in <module>
#      29     for line in PTS1:
#      30         for i in range(14486):
# ---> 31             if line == l[0][i]:
#      32                 f.write(l[j][i+1])
#      33                 f.write('\t')
#
# KeyboardInterrupt:

# %%
#NewPT2-2
l_meta = []
Extract_4hours_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_4hours_GSE139107_MouseIRI.metadata.txt"

Extract_4hours_meta_f = open(Extract_4hours_meta,'r',encoding='utf-8')
for line in Extract_4hours_meta_f:
    l_meta.append(line.split())
    
NewPT2  = []

for line in l_meta:
    if line[3] == 'NewPT2':
        NewPT2.append(line[0]) 

f = open('Norm2_4hour_NewPT2.txt','w')

for line in NewPT2:
    f.write(line)
    f.write('\t')
f.write('\n')

Extract_4hours = "/Users/sakitakeshita/Desktop/ドライ解析/Dataset_Paper/Processed_data/Extract_Norm_4h.txt"

Extract_4hours_f = open(Extract_4hours,'r',encoding='utf-8')
l = []
for line in Extract_4hours_f:
    l.append(line.split())

f.write("Slc1a5")
f.write('\t')
for line in NewPT2:
    for i in range(14486):
        if line == l[0][i]:
            f.write(l[1][i+1])
            f.write('\t')
f.write('\n')

f.write("Slc5a8")
f.write('\t')
for line in NewPT2:
    for i in range(14486):
        if line == l[0][i]:
            f.write(l[2][i+1])
            f.write('\t')
f.write('\n')

f.write("Slc5a12")
f.write('\t')
for line in NewPT2:
    for i in range(14486):
        if line == l[0][i]:
            f.write(l[3][i+1])
            f.write('\t')
f.write('\n')

print(len(NewPT2))
f.close()
# Out:
# 264

# %%
#PTS1 new file
PTS1 = []

meta = []
Ext_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_4hours_GSE139107_MouseIRI.metadata.txt"

Ext_meta_f = open(Ext_meta,'r',encoding='utf-8')
for line in Ext_meta_f:
    meta.append(line.split())

for line in meta:
    if line[3] == 'PTS1':
        PTS1.append(line[0]) 
        
f = open('Speed_4hours_PTS1.txt','w')

four = "/Users/sakitakeshita/Desktop/ドライ解析/Dataset_Paper/Processed_data/Processed_data_from_GEO/GSE139107_MouseIRI_4hours.dge.txt"
four_f = open(four,'r',encoding='utf-8')

l = []
for line in four_f:
    l.append(line.split())

#Cell Barcodesを書く
k = 0
for j in range(1,27134):
    f.write(l[j][0])
    f.write('\t')
    for line in PTS1:
        for i in range(k,14486): 
            if line == l[0][i]:
                f.write(l[j][i+1])
                f.write('\t')
                break
    f.write('\n')
    
f.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-abd1b11bf2d5> in <module>
#      29     for line in PTS1:
#      30         for i in range(k,14486):
# ---> 31             if line == l[0][i]:
#      32                 f.write(l[j][i+1])
#      33                 f.write('\t')
#
# KeyboardInterrupt:

# %%
#PTS1 new file
PTS1 = []

meta = []
Ext_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_4hours_GSE139107_MouseIRI.metadata.txt"

Ext_meta_f = open(Ext_meta,'r',encoding='utf-8')
for line in Ext_meta_f:
    meta.append(line.split())

for line in meta:
    if line[3] == 'PTS1':
        PTS1.append(line[0]) 
        
f = open('SpeedTest2_4hours_PTS1.txt','w')

for line in PTS1:
    f.write(line)
    f.write('\t')
f.write('\n')

four = "/Users/sakitakeshita/Desktop/ドライ解析/Dataset_Paper/Processed_data/Processed_data_from_GEO/GSE139107_MouseIRI_4hours.dge.txt"
four_f = open(four,'r',encoding='utf-8')

l = []
for line in four_f:
    l.append(line.split())


for j in range(1,27134):
    f.write(l[j][0])
    f.write('\t')
    k = 0
    for line in PTS1:
        for i in range(k,14486): 
            if line == l[0][i]:
                f.write(l[j][i+1])
                f.write('\t')
                k = i
                break
    f.write('\n')
    
f.close()

# %%
#PTS2 new file
PTS2 = []

meta = []
Ext_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_4hours_GSE139107_MouseIRI.metadata.txt"

Ext_meta_f = open(Ext_meta,'r',encoding='utf-8')
for line in Ext_meta_f:
    meta.append(line.split())

for line in meta:
    if line[3] == 'PTS2':
        PTS2.append(line[0]) 
        
f = open('SpeedTest_4hours_PTS2.txt','w')

for line in PTS2:
    f.write(line)
    f.write('\t')
f.write('\n')

four = "/Users/sakitakeshita/Desktop/ドライ解析/Dataset_Paper/Processed_data/Processed_data_from_GEO/GSE139107_MouseIRI_4hours.dge.txt"
four_f = open(four,'r',encoding='utf-8')

l = []
for line in four_f:
    l.append(line.split())


for j in range(1,27134):
    f.write(l[j][0])
    f.write('\t')
    k = 0
    for line in PTS2:
        for i in range(k,14486): 
            if line == l[0][i]:
                f.write(l[j][i+1])
                f.write('\t')
                k = i
                break
    f.write('\n')
    
f.close()

# %%
#PTS3 new file
PTS3 = []

meta = []
Ext_meta = "/Users/sakitakeshita/Library/Mobile Documents/com~apple~TextEdit/Documents/Extract_4hours_GSE139107_MouseIRI.metadata.txt"

Ext_meta_f = open(Ext_meta,'r',encoding='utf-8')
for line in Ext_meta_f:
    meta.append(line.split())

for line in meta:
    if line[3] == 'PTS3':
        PTS3.append(line[0]) 
        
f = open('SpeedTest_4hours_PTS3.txt','w')

for line in PTS3:
    f.write(line)
    f.write('\t')
f.write('\n')

four = "/Users/sakitakeshita/Desktop/ドライ解析/Dataset_Paper/Processed_data/Processed_data_from_GEO/GSE139107_MouseIRI_4hours.dge.txt"
four_f = open(four,'r',encoding='utf-8')

l = []
for line in four_f:
    l.append(line.split())


for j in range(1,27134):
    f.write(l[j][0])
    f.write('\t')
    k = 0
    for line in PTS3:
        for i in range(k,14486): 
            if line == l[0][i]:
                f.write(l[j][i+1])
                f.write('\t')
                k = i
                break
    f.write('\n')
    
f.close()
